# %% [markdown]
# #### 1.1 Bilangan Pembagi
# Buatlah flowchart (tidak harus menggunakan flogorithm) untuk menampilkan bilangan-bilangan pembagi
# yang sama (antara dua buah bilangan, yang merupakan inputan dari user), dan dari bilangan pembagi
# tersebut, tampilkan bilangan pembagi terbesar. Implementasikan flowchart yang sudah dibuat (bukan
# generate dari flowgorithm) dengan menggunakan bahasa Python, sehingga menghasilkan output seperti
# contoh-contoh yang terdapat pada Gambar 1.
# gambar 1(a)Bilangan Pembagi
# ![image.png](data:image/png;base64,...)
# gambar 1(b)Bilangan Pembagi
# ![image.png](data:image/png;base64,...)
# gambar 1(c)Bilangan Pembagi
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)

# %%
pertama=int(input('masukkan bilangan pertama ='))
kedua=int(input('masukkan bilangan kedua ='))
temp=1
beda=1
for i in range(1,pertama+1):
    if pertama%i==0 and kedua%i==0:
        print('pembagi yang sama-',temp,'=',i)
        temp=temp+1
print('pembagi yang sama terbesar adalah',i)
# Out:
# masukkan bilangan pertama =20
# masukkan bilangan kedua =100
# pembagi yang sama- 1 = 1
# pembagi yang sama- 2 = 2
# pembagi yang sama- 3 = 4
# pembagi yang sama- 4 = 5
# pembagi yang sama- 5 = 10
# pembagi yang sama- 6 = 20
# pembagi yang sama terbesar adalah 20

# %% [markdown]
# #### 1.2	Pemecahan bilangan
# Buat flowchart dan implementasikan flowchart tersebut (bukan generate code dari flowchart) untuk membagi bilangan menjadi bagian ratusan ribu, puluhan ribu, ribuan,ratusan, puluhan, dan satuan. Dimana bilangna yang akan dibagi adalah inputan dari user. Contoh output dapat dilihat pada Gambar 2
#
# Gambar 2(a): Pemecahan bilangan
# ![image.png](data:image/png;base64,...)
# Gambar 2(b): Pemecahan bilangan
# ![image.png](data:image/png;base64,...)
# Gambar 2(c): Pemecahan bilangan
# ![image.png](data:image/png;base64,...)
# Gambar 2(d): Pemecahan bilangan
# ![image.png](data:image/png;base64,...)
#
# flowchart
# ![image.png](data:image/png;base64,...)

# %%
temp=100000
a=int(input('masukkan angka='))
for i in range(1,7):
    g=a//temp
    a=a-g*temp
    print(i,':',g,'x',temp)
    temp=temp//10
# Out:
# masukkan angka=500055
# 1 : 5 x 100000
# 2 : 0 x 10000
# 3 : 0 x 1000
# 4 : 0 x 100
# 5 : 5 x 10
# 6 : 5 x 1
